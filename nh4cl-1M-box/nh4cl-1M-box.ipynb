# %% [markdown]
# ### 1. Modify topology topol.top file, chage forcefield.itp file

# %%
# !cat charmm-gui/topol.top
# Out:
# ;;
# ;; Generated by CHARMM-GUI FF-Converter
# ;;
# ;; Correspondance:
# ;; jul316@lehigh.edu or wonpil@lehigh.edu
# ;;
# ;; The main GROMACS topology file
# ;;
#
# ; Include forcefield parameters
# #include "toppar/forcefield.itp"
#
# [ moleculetype ]
# ; name	nrexcl
# NH4	     2
#
# [ atoms ]
# ; nr	type	resnr	residu	atom	cgnr	charge	mass
#      1       HGP2      1      NH4    HZ1      1     0.330000     1.0080   ; qtot  0.330
#      2      NG3P3      1      NH4     NZ      2    -0.320000    14.0070   ; qtot  0.010
#      3       HGP2      1      NH4    HZ2      3     0.330000     1.0080   ; qtot  0.340
#      4       HGP2      1      NH4    HZ3      4     0.330000     1.0080   ; qtot  0.670
#      5       HGP2      1      NH4    HZ4      5     0.330000     1.0080   ; qtot  1.000
#
# [ bonds ]
# ; ai	aj	funct	b0	Kb
#     2     1     1
#     2     3     1
#     2     4     1
#     2     5     1
#
# [ angles ]
# ; ai	aj	ak	funct	th0	cth	S0	Kub
#     1     2     3     5
#     1     2     4     5
#     1     2     5     5
#     3     2     4     5
#     3     2     5     5
#     4     2     5     5
#
# [ moleculetype ]
# ; name	nrexcl
# CLA	     1
#
# [ atoms ]
# ; nr	type	resnr	residu	atom	cgnr	charge	mass
#      1        CLA    230      CLA    CLA      1    -1.000000    35.4500   ; qtot -1.000
#
# #include "toppar/TIP3.itp"
#
# [ system ]
# ; Name
# Title
#
# [ molecules ]
# ; Compound	#mols
# TIP3  	       10850

# %% [markdown]
# ### 2. Copy mdp file ions.mdp
# ### 3. Make tpr file

# %%
# !gmx grompp -f ions.mdp -c charmm-gui/step3_input.gro -p charmm-gui/topol.top -o step2_ions.tpr
# Out:
#                  :-) GROMACS - gmx grompp, 2025.1-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.1/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.1
# Working dir:  /Users/heiley/Desktop/SURP/1050
# Command line:
#   gmx grompp -f ions.mdp -c charmm-gui/step3_input.gro -p charmm-gui/topol.top -o step2_ions.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file ions.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to 2088533999
#
# Generated 1631 of the 1653 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 833 of the 1653 1-4 parameter combinations
#
# Excluding 2 bonded neighbours molecule type 'TIP3'
# Analysing residue names:
# There are: 10850      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 65097.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 2 [file ions.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# This run will generate roughly 3 Mb of data
#
# There were 2 NOTEs
#
# GROMACS reminds you: "No great discovery was ever made without a bold guess." (Marie Curie)

# %% [markdown]
# ### 4. Copy NH4+ and CLA- pdb files NH4.pdb and CLA.pdb
# ### 5. Add NH4+

# %%
# !gmx insert-molecules -f step2_ions.tpr -ci NH4.pdb -conc 1 -o step3_NH4.gro -try 30

# %% [markdown]
# ### 6. Insert Cl- ions

# %%
# !gmx insert-molecules -f step3_NH4.gro -ci CLA.pdb -conc 1 -o step3_NH4Cl.gro -try 30
# Out:
#             :-) GROMACS - gmx insert-molecules, 2025.1-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.1/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.1
# Working dir:  /Users/heiley/Desktop/SURP/1050
# Command line:
#   gmx insert-molecules -f step3_NH4.gro -ci CLA.pdb -conc 1 -o step3_NH4Cl.gro -try 30
#
# Reading solute configuration
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gm
# Try 926 success (now 33738 atoms)!
# Try 929 success (now 33739 atoms)!
# Try 936 success (now 33740 atoms)!
# Try 939 success (now 33741 atoms)!
# Try 940 success (now 33742 atoms)!
# Try 943 success (now 33743 atoms)!
# Try 955 success (now 33744 atoms)!
# Try 961 success (now 33745 atoms)!
# Try 964 success (now 33746 atoms)!
# Try 966 success (now 33747 atoms)!
# Try 968 success (now 33748 atoms)!
# Try 971 success (now 33749 atoms)!
# Try 973 success (now 33750 atoms)!
# Try 990 success (now 33751 atoms)!
# Try 991 success (now 33752 atoms)!
# Try 1009 success (now 33753 atoms)!
# Try 1018 success (now 33754 atoms)!
# Try 1020 success (now 33755 atoms)!
# Try 1024 success (now 33756 atoms)!
# Try 1025 success (now 33757 atoms)!
# Try 1034 success (now 33758 atoms)!
# Try 1036 success (now 33759 atoms)!
# Try 1037 success (now 33760 atoms)!
# Try 1038 success (now 33761 atoms)!
# Try 1040 success (now 33762 atoms)!
# Try 1047 success (now 33763 atoms)!
# Try 1052 success (now 33764 atoms)!
# Try 1056 success (now 33765 atoms)!
# Try 1059 success (now 33766 atoms)!
# Try 1063 success (now 33767 atoms)!
# Try 1065 success (now 33768 atoms)!
# Try 1067 success (now 33769 atoms)!
# Try 1076 success (now 33770 atoms)!
# Try 1081 success (now 33771 atoms)!
# Try 1098 success (now 33772 atoms)!
# Try 1099 success (now 33773 atoms)!
# Try 1107 success (now 33774 atoms)!
# Try 1119 success (now 33775 atoms)!
# Try 1127 success (now 33776 atoms)!
# Try 1128 success (now 33777 atoms)!
# Try 1135 success (now 33778 atoms)!
# Try 1141 success (now 33779 atoms)!
# Try 1149 success (now 33780 atoms)!
# Try 1159 success (now 33781 atoms)!
# Try 1169 success (now 33782 atoms)!
# Try 1170 success (now 33783 atoms)!
# Try 1185 success (now 33784 atoms)!
# Try 1187 success (now 33785 atoms)!
# Try 1189 success (now 33786 atoms)!
# Try 1190 success (now 33787 atoms)!
# Try 1204 success (now 33788 atoms)!
# Try 1208 success (now 33789 atoms)!
# Try 1223 success (now 33790 atoms)!
# Try 1225 success (now 33791 atoms)!
# Try 1230 success (now 33792 atoms)!
#
# Added 207 molecules (out of 207 requested)
# Writing generated configuration to step3_NH4Cl.gro
#
# Output configuration contains 33792 atoms in 11264 residues
#
# GROMACS reminds you: "That Was Pretty Cool" (Beavis)

# %% [markdown]
# ### 7. Modify top file topol.top to account for new ions

# %%
# !cat charmm-gui/topol.top
# Out:
# ;;
# ;; Generated by CHARMM-GUI FF-Converter
# ;;
# ;; Correspondance:
# ;; jul316@lehigh.edu or wonpil@lehigh.edu
# ;;
# ;; The main GROMACS topology file
# ;;
#
# ; Include forcefield parameters
# #include "toppar/forcefield.itp"
#
# [ moleculetype ]
# ; name	nrexcl
# NH4	     2
#
# [ atoms ]
# ; nr	type	resnr	residu	atom	cgnr	charge	mass
#      1       HGP2      1      NH4    HZ1      1     0.330000     1.0080   ; qtot  0.330
#      2      NG3P3      1      NH4     NZ      2    -0.320000    14.0070   ; qtot  0.010
#      3       HGP2      1      NH4    HZ2      3     0.330000     1.0080   ; qtot  0.340
#      4       HGP2      1      NH4    HZ3      4     0.330000     1.0080   ; qtot  0.670
#      5       HGP2      1      NH4    HZ4      5     0.330000     1.0080   ; qtot  1.000
#
# [ bonds ]
# ; ai	aj	funct	b0	Kb
#     2     1     1
#     2     3     1
#     2     4     1
#     2     5     1
#
# [ angles ]
# ; ai	aj	ak	funct	th0	cth	S0	Kub
#     1     2     3     5
#     1     2     4     5
#     1     2     5     5
#     3     2     4     5
#     3     2     5     5
#     4     2     5     5
#
# [ moleculetype ]
# ; name	nrexcl
# CLA	     1
#
# [ atoms ]
# ; nr	type	resnr	residu	atom	cgnr	charge	mass
#      1        CLA    230      CLA    CLA      1    -1.000000    35.4500   ; qtot -1.000
#
# #include "toppar/TIP3.itp"
#
# [ system ]
# ; Name
# Title
#
# [ molecules ]
# ; Compound	#mols
# TIP3  	       10850
# NH4  	       207
# CLA  	       207

# %% [markdown]
# ### 8. Make tpr file

# %%
# !gmx grompp -f charmm-gui/step4.0_minimization.mdp -c step3_NH4Cl.gro -p charmm-gui/topol.top -o step4_minimization.tpr -maxwarn 1
# Out:
#                  :-) GROMACS - gmx grompp, 2025.1-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.1/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.1
# Working dir:  /Users/heiley/Desktop/SURP/1050
# Command line:
#   gmx grompp -f charmm-gui/step4.0_minimization.mdp -c step3_NH4Cl.gro -p charmm-gui/topol.top -o step4_minimization.tpr -maxwarn 1
#
# Setting the LD random seed to -33654531
#
# Generated 1631 of the 1653 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 833 of the 1653 1-4 parameter combinations
#
# Excluding 2 bonded neighbours molecule type 'TIP3'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'NH4'
#
# turning H bonds into constraints...
#
# Excluding 1 bonded neighbours molecule type 'CLA'
#
# turning H bonds into constraints...
#
# WARNING 1 [file topol.top, line 59]:
#   The following macros were defined in the 'define' mdp field with the -D
#   prefix, but were not used in the topology:
#       POSRES_FC_SC
#       POSRES_FC_BB
#       POSRES
#   If you haven't made a spelling error, either use the macro you defined,
#   or don't define the macro
#
# Analysing residue names:
# There are: 11264      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 67995.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# The largest distance between excluded atoms is 0.171 nm between atom 33003 and 33004
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 60x60x60, spacing 0.117 0.117 0.117
#
# Estimate for the relative computational load of the PME mesh part: 0.13
#
# This run will generate roughly 3 Mb of data
#
# There was 1 WARNING
#
# GROMACS reminds you: "Lunatics On Pogo Sticks" (Red Hot Chili Peppers)

# %% [markdown]
# ### 9. minimisation run

# %%
# !gmx mdrun -v -deffnm step4_minimization -s step4_minimization.tpr
# Out:
#                   :-) GROMACS - gmx mdrun, 2025.1-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.1/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.1
# Working dir:  /Users/heiley/Desktop/SURP/1050
# Command line:
#   gmx mdrun -v -deffnm step4_minimization -s step4_minimization.tpr
#
# Reading file step4_minimization.tpr, VERSION 2025.1-Homebrew (single precision)
# Using 1 MPI thread
# Using 8 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+03
#    Number of steps    =         5000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  1.61454e+04 Fmax= 7.12417e+05, atom= 33788
# Step=    1, Dmax= 1.0e-02 nm, Epot= -9.74354e+04 Fmax= 2.43407e+05, atom= 33660
# Step=    2, Dmax= 1.2e-02 nm, Epot= -2.28447e+05 Fmax= 1.16187e+05, atom= 33783
# Step=    3, Dmax= 1.4e-02 nm, Epot= -3.19230e+05 Fmax= 5.30824e+04, atom= 33788
# Step=    4, Dmax= 1.7e-02 nm, Epot= -3.94871e+05 Fmax= 2.36386e+04, atom= 33753
# Step=    5, Dmax= 2.1e-02 nm, Epot= -4.56162e+05 Fmax= 1.78428e+04, atom= 33767
# Step=    6, Dmax= 2.5e-02 nm, Epot= -4.88128e+05 Fmax= 2.05373e+04, atom= 33767
# Step=    7, Dmax= 3.0e-02 nm, Epot= -5.05585e+05 Fmax= 1.72245e+04, atom= 33767
# Step=    8, Dmax= 3.6e-02 nm, Epot= -5.21879e+05 Fmax= 1.20422e+04, atom= 33767
# Step=    9, Dmax= 4.3e-02 nm, Epot= -5.39772e+05 Fmax= 2.09740e+04, atom= 33767
# Step=   10, Dmax= 5.2e-02 nm, Epot= -5.47962e+05 Fmax= 7.09114e+03, atom= 33767
# Step=   11, Dmax= 6.2e-02 nm, Epot= -5.66154e+05 Fmax= 6.19037e+04, atom= 33736
# Step=   12, Dmax= 7.4e-02 nm, Epot= -5.68853e+05 Fmax= 1.02797e+04, atom= 33736
# Step=   13, Dmax= 8.9e-02 nm, Epot= -5.77993e+05 Fmax= 2.98912e+04, atom= 33736
# Step=   14, Dmax= 1.1e-01 nm, Epot= -5.81045e+05 Fmax= 6.19611e+03, atom= 24772
#
# Step 15, time 0.015 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002231, max 0.040457 (between atoms 32842 and 32845)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32842  32841   32.0    0.1040   0.1001      0.1040
#   32842  32843   34.6    0.1040   0.1008      0.1040
#   32842  32845   38.9    0.1040   0.0998      0.1040
#
# step 15: One or more water molecules can not be settled.
# Check for bad contacts and/or reduce the timestep if appropriate.
# Wrote pdb files with previous and current coordinates
# Step=   15, Dmax= 1.3e-01 nm, Epot=          inf Fmax= 2.98912e+04, atom= 33736
# step 16: One or more water molecules can not be settled.
# Check for bad contacts and/or reduce the timestep if appropriate.
# Wrote pdb files with previous and current coordinates
# Step=   17, Dmax= 3.2e-02 nm, Epot= -5.84819e+05 Fmax= 2.13226e+03, atom= 32843
#
# Step 18, time 0.018 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002324, max 0.039388 (between atoms 32842 and 32845)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32842  32841   31.7    0.1040   0.1079      0.1040
#   32842  32843   33.9    0.1040   0.1080      0.1040
#   32842  32845   41.6    0.1040   0.1081      0.1040
# Step=   18, Dmax= 3.9e-02 nm, Epot= -5.94254e+05 Fmax= 8.42455e+03, atom= 32842
#
# Step 19, time 0.019 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000831, max 0.014098 (between atoms 32842 and 32841)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32842  32841   32.0    0.1079   0.1055      0.1040
#   32842  32843   31.7    0.1080   0.1054      0.1040
#   32842  32845   32.3    0.1081   0.1054      0.1040
# Step=   19, Dmax= 4.6e-02 nm, Epot= -5.96555e+05 Fmax= 1.81157e+03, atom= 32843
#
# Step 20, time 0.02 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.005324, max 0.098464 (between atoms 32842 and 32841)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32842  32841

# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33423   33.3    0.1050   0.1051      0.1040
#   33422  33424   38.5    0.1043   0.1060      0.1040
# Step=   42, Dmax= 3.8e-02 nm, Epot= -6.30063e+05 Fmax= 3.63378e+03, atom= 33421
#
# Step 43, time 0.043 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002050, max 0.040617 (between atoms 33422 and 33423)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33423   40.9    0.1051   0.1082      0.1040
#   33422  33424   40.6    0.1060   0.1062      0.1040
# Step=   43, Dmax= 4.6e-02 nm, Epot= -6.30775e+05 Fmax= 3.67052e+03, atom= 33425
#
# Step 44, time 0.044 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.003584, max 0.064955 (between atoms 33422 and 33424)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33421   35.4    0.1064   0.1066      0.1040
#   33422  33423   50.1    0.1082   0.1074      0.1040
#   33422  33424   51.9    0.1062   0.1108      0.1040
#   33422  33425   32.1    0.1054   0.1082      0.1040
#   32697  32696   36.1    0.1049   0.1050      0.1040
#   32697  32699   37.4    0.1044   0.1060      0.1040
#   33122  33124   34.4    0.1052   0.1029      0.1040
#   33122  33125   35.1    0.1052   0.1030      0.1040
# Step=   44, Dmax= 5.5e-02 nm, Epot= -6.30801e+05 Fmax= 5.48909e+03, atom= 33424
#
# Step 45, time 0.045 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.008019, max 0.124813 (between atoms 33422 and 33424)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33421   35.8    0.1066   0.1039      0.1040
#   33422  33423   69.9    0.1074   0.1143      0.1040
#   33422  33424   51.1    0.1108   0.1170      0.1040
#   33422  33425   36.3    0.1082   0.1079      0.1040
#   32697  32696   46.3    0.1050   0.1086      0.1040
#   32697  32699   39.8    0.1060   0.1075      0.1040
#   33122  33121   43.2    0.1026   0.1117      0.1040
#   33122  33124   50.9    0.1029   0.1130      0.1040
#   33122  33125   49.7    0.1030   0.1131      0.1040
# Step=   45, Dmax= 6.6e-02 nm, Epot= -6.31466e+05 Fmax= 6.10977e+03, atom= 12394
#
# Step 46, time 0.046 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.006566, max 0.112987 (between atoms 33422 and 33424)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33421   34.9    0.1039   0.1119      0.1040
#   33422  33423   60.0    0.1143   0.1114      0.1040
#   33422  33424   46.6    0.1170   0.1158      0.1040
#   33422  33425   34.7    0.1079   0.1063      0.1040
#   32697  32696   38.7    0.1086   0.1056      0.1040
#   32697  32699   34.2    0.1075   0.1067      0.1040
#   33122  33121   48.2    0.1117   0.1088      0.1040
#   33122  33124   46.5    0.1130   0.1087      0.1040
#   33122  33125   44.9    0.1131   0.1087      0.1040
#   33217  33216   31.7    0.1037   0.1063      0.1040
#
# step 46: One or more water molecules can not be settled.
# Check for bad contacts and/or reduce the timestep if appropriate.
# Wrote pdb files with previous and current coordinates
# Step=   47, Dmax= 4.0e-02 nm, Epot= -6.33131e+05 Fmax= 2.91128e+03, atom= 33423
#
# Step 48, time 0.048 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001518, max 0.037187 (between atoms 33422 and 33424)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33423   44.4    0.1051   0.1020      0.1040
#   33422  33424   31.5    0.1055   0.1001      0.1040
# Step=   48, Dmax= 4.8e-02 nm, Epot= -6.33988e+05 Fmax= 2.96464e+03, atom= 33424
#
# Step 49, time 0.049 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.003037, max 0.048008 (between atoms 33422 and 33424)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33423   48.6    0.1020   0.1058      0.1040
#   33422  33424   33.0    0.1001   0.1090      0.1040
#   33422  33425   31.3    0.1050   0.1081      0.1040
# Step=   49, Dmax= 5.7e-02 nm, Epot= -6.34675e+05 Fmax= 3.52312e+03, atom= 33422
#
# Step 50, time 0.05 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.010228, max 0.261174 (between atoms 33422 and 33423)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33421   47.1    0.1078   0.1049      0.1040
#   33422  33423   88.6    0.1058   0.1312      0.1040
#   33422  33424   88.2    0.1090   0.1125      0.1040
#   33422  33425   53.5    0.1081   0.1040      0.1040
#   32697  32696   45.5    0.1056   0.1035      0.1040
#   32697  32699   45.0    0.1060   0.1036      0.1040
#   32697  32700   43.2    0.1060   0.1038      0.1040
#   33122  33121   66.6    0.1062   0.1022      0.1040
#   33122  33124   66.7    0.1055   0.1102      0.1040
#   33122  33125   52.8    0.1058   0.1057      0.1040
#   33087  33088   36.2    0.1046   0.1010      0.1040
#   33087  33089   38.5    0.1046   0.1012      0.1040
#   33087  33090   43.4    0.1046   0.1008      0.1040
# Step=   50, Dmax= 6.9e-02 nm, Epot= -6.33102e+05 Fmax= 7.57690e+03, atom= 33124
# Step 51, time 0.051 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000532, max 0.008602 (between atoms 33422 and 33423)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33423   39.9    0.1058   0.1049      0.1040
#   33422  33424   33.5    0.1090   0.1041      0.1040
# Step=   51, Dmax= 3.4e-02 nm, Epot= -6.35585e+05 Fmax= 2.68785e+03, atom= 33424
#
# Step 52, time 0.052 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001504, max 0.022690 (between atoms 33422 and 33424)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33423   33.7    0.1049   0.1054      0.1040
# Step=   52, Dmax= 4.1e-02 nm, Epot= -6.36186e+05 Fmax= 2.55921e+03, atom= 33087
#
# Step 53, time 0.053 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002413, max 0.027502 (between atoms 33087 and 33089)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33421   33.8    0.1057   0.1048      0.1040
#   33422  33423   50.2    0.1054   0.1056      0.1040
#   33422  33424   44.6    0.1064   0.1042      0.1040
#   33422  33425   36.9    0.1061   0.1048      0.1040
#   33122  33121   38.5    0.1047   0.1024      0.1040
#   33122  33124   36.9    0.1045   0.1036      0.1040
#   33087  33088   40.4    0.1050   0.1012      0.1040
#   33087  33089   41.5    0.1050   0.1011      0.1040
#   33087  33090   44.4    0.1050   0.1012      0.1040
#   32787  32786   32.6    0.1043   0.1022      0.1040
#   32787  32790   30.3    0.1043   0.1025      0.1040
# Step=   54, Dmax= 2.5e-02 nm, Epot= -6.36916e+05 Fmax= 1.52834e+03, atom= 33423
# Step=   55, Dmax= 3.0e-02 nm, Epot= -6.37229e+05 Fmax= 3.27032e+03, atom= 33087
#
# Step 56, time 0.056 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000464, max 0.003968 (between atoms 33422 and 33423)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33423   31.1    0.1046   0.1044      0.1040
# Step=   56, Dmax= 3.6e-02 nm, Epot= -6.37959e+05 Fmax= 2.40147e+03, atom= 32788
#
# Step 57, time 0.057 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.005475, max 0.054785 (between atoms 33087 and 33088)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33422  33423   35.6    0.1044   0.1052      0.1040
#   33122  33121   35.9    0.1038   0.1080      0.1040
#   33122  33124   38.6    0.1038   0.1086      0.1040
#   33122  33125   34.3    0.1036   0.1082      0.1040
#   33087  33088   40.8    0.1042   0.1097      0.1040
#   33087  33089   40.7    0.1042   0.1093      0.1040
#   33087  33090   35.8    0.1041   0.1093      0.1040
#   32787  32786   42.2    0.1038   0.1090      0.1040
#   32787  32788   33.4    0.1036   0.1096      0.1040
#   32787  32790   43.2    0.1039   0.1086      0.1040
# Step=   58, Dmax= 2.1e-02 nm, Epot= -6.38767e+05 Fmax= 1.24544e+03, atom= 32789
# Step=   59, Dmax= 2.6e-02 nm, Epot= -6.38942e+05 Fmax= 3.56229e+03, atom= 32786
# Step=   60, Dmax= 3.1e-02 nm, Epot= -6.39930e+05 Fmax= 1.93822e+03, atom= 32789
#
# Step 61, time 0.061 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001796, max 0.021725 (between atoms 32787 and 32788)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33122  33124   31.9    0.1055   0.1025      0.1040
#   32787  32786   35.1    0.1059   0.1019      0.1040
#   32787  32790   34.8    0.1058   0.1018      0.1040
# Step=   62, Dmax= 1.9e-02 nm, Epot= -6.40517e+05 Fmax= 1.04520e+03, atom= 32787
# Step=   63, Dmax= 2.2e-02 nm, Epot= -6.40823e+05 Fmax= 3.76780e+03, atom= 33737
# Step=   64, Dmax= 2.7e-02 nm, Epot= -6.41719e+05 Fmax= 1.49379e+03, atom= 33737
# Step=   65, Dmax= 3.2e-02 nm, Epot= -6.42298e+05 Fmax= 6.67409e+03, atom= 33737
# Step=   66, Dmax= 3.8e-02 nm, Epot= -6.42791e+05 Fmax= 1.71353e+03, atom= 33737
#
# Step 67, time 0.067 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000616, max 0.012230 (between atoms 33122 and 33123)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33122  33124   30.3    0.1046   0.1034      0.1040
#   33122  33125   32.9    0.1047   0.1034      0.1040
# Step=   67, Dmax= 4.6e-02 nm, Epot= -6.43358e+05 Fmax= 1.70255e+04, atom= 33737
# Step=   68, Dmax= 5.5e-02 nm, Epot= -6.43907e+05 Fmax= 1.77956e+03, atom= 33737
#
# Step 69, time 0.069 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000840, max 0.014336 (between atoms 33122 and 33124)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33122  33125   32.5    0.1045   0.1025      0.1040
# Step=   69, Dmax= 6.6e-02 nm, Epot= -6.44960e+05 Fmax= 4.51030e+03, atom= 33125
#
# Step 70, time 0.07 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.015244, max 0.272809 (between atoms 33122 and 33121)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33122  33121   64.1    0.1030   0.1324      0.1040
#   33122  33124   58.7    0.1025   0.1316      0.1040
#   33122  33125   91.5    0.1025   0.1263      0.1040
# Step=   70, Dmax= 8.0e-02 nm, Epot= -6.45083e+05 Fmax= 4.55111e+03, atom= 33125
#
# Step 71, time 0.071 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.053548, max 1.079160 (between atoms 33122 and 33125)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   47.9    0.1037   0.1142      0.1040
#   32807  32809   48.1    0.1037   0.1148      0.1040
#   32807  32810   51.7    0.1037   0.1141      0.1040
#   33122  33121   89.9    0.1324   0.1873      0.1040
#   33122  33124   89.4    0.1316   0.1800      0.1040
#   33122  33125   89.6    0.1263   0.2162      0.1040
#   32787  32786   66.8    0.1053   0.1000      0.1040
#   32787  32788   50.5    0.1053   0.1028      0.1040
#   32787  32790   52.0    0.1053   0.1027      0.1040
# Wrote pdb files with previous and current coordinates
# Step=   71, Dmax= 9.6e-02 nm, Epot=          inf Fmax= 4.51030e+03, atom= 33125
# Step 72, time 0.072 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.008133, max 0.147096 (between atoms 33122 and 33124)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33122  33121   52.7    0.1324   0.1171      0.1040
#   33122  33124   49.3    0.1316   0.1193      0.1040
#   33122  33125   61.3    0.1263   0.1175      0.1040
# Step=   72, Dmax= 4.8e-02 nm, Epot= -6.46014e+05 Fmax= 2.20390e+03, atom= 33123
#
# Step 73, time 0.073 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.007472, max 0.084100 (between atoms 32807 and 32810)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   51.7    0.1051   0.0959      0.1040
#   32807  32809   46.4    0.1052   0.0953      0.1040
#   32807  32810   55.7    0.1052   0.0953      0.1040
#   33122  33121   44.5    0.1171   0.0959      0.1040
#   33122  33123   50.4    0.1036   0.0965      0.1040
#   32787  32786   44.5    0.1038   0.1115      0.1040
#   32787  32788   41.2    0.1040   0.1111      0.1040
#   32787  32790   43.1    0.1040   0.1102      0.1040
# Step=   74, Dmax= 2.9e-02 nm, Epot= -6.46367e+05 Fmax= 2.51749e+03, atom= 32808
#
# Step 75, time 0.075 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002211, max 0.036228 (between atoms 32807 and 32809)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   32.7    0.1033   0.1075      0.1040
#   32807  32809   32.4    0.1033   0.1078      0.1040
#   32807  32810   35.2    0.1033   0.1076      0.1040
# Step=   75, Dmax= 3.4e-02 nm, Epot= -6.46657e+05 Fmax= 3.24451e+03, atom= 32807
#
# Step 76, time 0.076 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001815, max 0.030051 (between atoms 32787 and 32788)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   37.5    0.1075   0.1046      0.1040
#   32807  32809   33.8    0.1078   0.1045      0.1040
#   32807  32810   38.3    0.1076   0.1044      0.1040
#   32787  32786   34.5    0.1034   0.1071      0.1040
#   32787  32790   32.7    0.1035   0.1068      0.1040
# Step=   76, Dmax= 4.1e-02 nm, Epot= -6.46990e+05 Fmax= 3.36422e+03, atom= 32808
#
# Step 77, time 0.077 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.005377, max 0.092769 (between atoms 32807 and 32809)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   46.7    0.1046   0.1124      0.1040
#   32807  32809   45.2    0.1045   0.1136      0.1040
#   32807  32810   51.2    0.1044   0.1132      0.1040
#   32787  32786   41.6    0.1071   0.1042      0.1040
#   32787  32788   33.3    0.1071   0.1039      0.1040
#   32787  32790   39.6    0.1068   0.1044      0.1040
# Step=   77, Dmax= 5.0e-02 nm, Epot= -6.47012e+05 Fmax= 4.12536e+03, atom= 32788
#
# Step 78, time 0.078 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.010578, max 0.152483 (between atoms 32787 and 32786)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   56.8    0.1124   0.1134      0.1040
#   32807  32809   48.4    0.1136   0.1130      0.1040
#   32807  32810   57.7    0.1132   0.1125      0.1040
#   33122  33121   36.1    0.1041   0.1059      0.1040
#   33312  33313   31.8    0.1046   0.1042      0.1040
#   33312  33315   34.4    0.1043   0.1054      0.1040
#   32787  32786   63.0    0.1042   0.1199      0.1040
#   32787  32788   51.5    0.1039   0.1195      0.1040
#   32787  32790   63.3    0.1044   0.1193      0.1040
# Step=   79, Dmax= 3.0e-02 nm, Epot= -6.48024e+05 Fmax= 1.32339e+03, atom= 32810
#
# Step 80, time 0.08 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001935, max 0.025311 (between atoms 32787 and 32786)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32810   33.4    0.1052   0.1018      0.1040
#   32787  32786   32.4    0.1055   0.1014      0.1040
#   32787  32790   33.3    0.1054   0.1015      0.1040
# Step=   80, Dmax= 3.6e-02 nm, Epot= -6.48207e+05 Fmax= 4.79753e+03, atom= 32786
#
# Step 81, time 0.081 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002607, max 0.037406 (between atoms 32787 and 32788)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   35.9    0.1017   0.1074      0.1040
#   32807  32809   30.0    0.1018   0.1074      0.1040
#   32807  32810   35.5    0.1018   0.1056      0.1040
#   32787  32786   32.0    0.1014   0.1069      0.1040
#   32787  32788   35.7    0.1019   0.1079      0.1040
#   32787  32790   35.4    0.1015   0.1063      0.1040
# Step=   81, Dmax= 4.3e-02 nm, Epot= -6.48910e+05 Fmax= 2.76054e+03, atom= 32807
#
# Step 82, time 0.082 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002617, max 0.037983 (between atoms 32807 and 32810)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   53.9    0.1074   0.1010      0.1040
#   32807  32809   46.8    0.1074   0.1002      0.1040
#   32807  32810   42.9    0.1056   0.1000      0.1040
#   32787  32786   42.8    0.1069   0.1021      0.1040
#   32787  32788   41.3    0.1079   0.1008      0.1040
#   32787  32790   43.0    0.1063   0.1014      0.1040
# Step=   83, Dmax= 2.6e-02 nm, Epot= -6.49325e+05 Fmax= 1.53658e+03, atom= 32808
# Step=   84, Dmax= 3.1e-02 nm, Epot= -6.49563e+05 Fmax= 3.51135e+03, atom= 32807
#
# Step 85, time 0.085 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000690, max 0.009721 (between atoms 32787 and 32789)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   33.2    0.1053   0.1048      0.1040
#   32807  32809   34.1    0.1053   0.1049      0.1040
#   32807  32810   31.4    0.1058   0.1042      0.1040
#   32787  32786   33.1    0.1046   0.1050      0.1040
# Step=   85, Dmax= 3.7e-02 nm, Epot= -6.49969e+05 Fmax= 2.87291e+03, atom= 32808
#
# Step 86, time 0.086 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002318, max 0.040689 (between atoms 32807 and 32810)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   33.9    0.1048   0.1061      0.1040
#   32807  32809   33.9    0.1049   0.1074      0.1040
#   32807  32810   34.2    0.1042   0.1082      0.1040
#   32787  32786   33.4    0.1050   0.1054      0.1040
#   32787  32790   32.7    0.1046   0.1063      0.1040
# Step=   86, Dmax= 4.4e-02 nm, Epot= -6.50129e+05 Fmax= 3.33639e+03, atom= 32806
#
# Step 87, time 0.087 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.003001, max 0.046755 (between atoms 32807 and 32808)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   56.0    0.1061   0.1089      0.1040
#   32807  32809   45.4    0.1074   0.1061      0.1040
#   32807  32810   50.8    0.1082   0.1052      0.1040
#   33312  33313   37.0    0.1040   0.1060      0.1040
#   33312  33315   30.5    0.1043   0.1050      0.1040
#   32787  32786   55.9    0.1054   0.1082      0.1040
#   32787  32788   38.3    0.1060   0.1042      0.1040
#   32787  32790   50.3    0.1063   0.1055      0.1040
# Step=   88, Dmax= 2.7e-02 nm, Epot= -6.50780e+05 Fmax= 1.26786e+03, atom= 32808
# Step=   89, Dmax= 3.2e-02 nm, Epot= -6.50932e+05 Fmax= 3.36979e+03, atom= 32787
#
# Step 90, time 0.09 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001545, max 0.015993 (between atoms 32787 and 32788)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   34.3    0.1052   0.1030      0.1040
#   33312  33313   42.7    0.1039   0.1053      0.1040
#   32787  32786   44.4    0.1045   0.1040      0.1040
#   32787  32788   31.1    0.1053   0.1023      0.1040
# Step=   90, Dmax= 3.8e-02 nm, Epot= -6.51085e+05 Fmax= 3.71231e+03, atom= 32786
#
# Step 91, time 0.091 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002663, max 0.043444 (between atoms 32787 and 32790)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   33312  33313   35.2    0.1053   0.1050      0.1040
#   33312  33315   30.7    0.1052   0.1065      0.1040
#   32787  32786   35.7    0.1040   0.1071      0.1040
#   32787  32788   30.6    0.1023   0.1060      0.1040
#   32787  32790   36.6    0.1035   0.1085      0.1040
# Step=   91, Dmax= 4.6e-02 nm, Epot= -6.51540e+05 Fmax= 2.88353e+03, atom= 32789
#
# Step 92, time 0.092 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.005199, max 0.055782 (between atoms 32787 and 32789)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32842  32841   33.1    0.1037   0.1074      0.1040
#   32842  32843   31.2    0.1037   0.1074      0.1040
#   32842  32844   32.4    0.1037   0.1074      0.1040
#   33252  33251   32.6    0.1037   0.1076      0.1040
#   33252  33253   35.7    0.1036   0.1077      0.1040
#   33252  33254   32.6    0.1037   0.1076      0.1040
#   32807  32808   45.0    0.1052   0.1049      0.1040
#   32807  32809   35.1    0.1060   0.1028      0.1040
#   32807  32810   52.4    0.1064   0.1016      0.1040
#   33357  33358   34.6    0.1042   0.1063      0.1040
#   33357  33360   34.9    0.1047   0.1050      0.1040
#   33122  33124   38.2    0.1044   0.1050      0.1040
#   33122  33125   36.2    0.1043   0.1062      0.1040
#   33312  33311   35.8    0.1055   0.1078      0.1040
#   33312  33313   39.6    0.1050   0.1090      0.1040
#   33312  33314   37.5    0.1057   0.1085      0.1040
#   33312  33315   44.6    0.1065   0.1061      0.1040
#   32787  32786   38.4    0.1071   0.1044      0.1040
#   32787  32788   47.7    0.1060   0.1078      0.1040
#   32787  32790   60.8    0.1085   0.1025      0.1040
# Step=   93, Dmax= 2.8e-02 nm, Epot= -6.52146e+05 Fmax= 1.53065e+03, atom= 33313
# Step=   95, Dmax= 1.7e-02 nm, Epot= -6.52486e+05 Fmax= 1.00952e+03, atom= 32806
# Step=   96, Dmax= 2.0e-02 nm, Epot= -6.52507e+05 Fmax= 2.47643e+03, atom= 32808
# Step=   97, Dmax= 2.4e-02 nm, Epot= -6.53065e+05 Fmax= 1.81170e+03, atom= 32806
# Step=   98, Dmax= 2.9e-02 nm, Epot= -6.53075e+05 Fmax= 3.04341e+03, atom= 32808
#
# Step 99, time 0.099 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002197, max 0.031132 (between atoms 32807 and 32809)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   31.1    0.1033   0.1069      0.1040
#   32807  32810   35.8    0.1031   0.1069      0.1040
#   32787  32790   31.4    0.1034   0.1059      0.1040
# Step=   99, Dmax= 3.4e-02 nm, Epot= -6.53379e+05 Fmax= 2.67076e+03, atom= 32806
#
# Step 100, time 0.1 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001396, max 0.011268 (between atoms 33312 and 33313)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#   32807  32808   37.1    0.1069   0.1038      0.1040
#   32807  32809   32.0    0.1072   0.1035      0.1040
#   32807  32810   40.6    0.1069   0.1033      0.1040
#   32787  32786   31.0    0.1060   0.1033      0.1040
#   32787  32788   31.8    0.1059   0.1034      0.1040
#   32787  32790   37.1    0.1059   0.1029      0.1040
# Step=  101, Dmax= 2.1e-02 nm, Epot= -6.54027e+05 Fmax= 6.87977e+02, atom= 33313
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to Fmax < 1000 in 102 steps
# Potential Energy  = -6.5402662e+05
# Maximum force     =  6.8797729e+02 on atom 33313
# Norm of force     =  3.0674674e+01
#
# GROMACS reminds you: "If Life Seems Jolly Rotten, There's Something You've Forgotten !" (Monty Python)

# %% [markdown]
# ### 10. Modify mdp group options to change group to molecule type
# ### 11. Make tpr file for equilibration

# %%
# !gmx grompp -f charmm-gui/step4.1_equilibration.mdp -o step5_equilibration.tpr -c step4_minimization.gro -r step3_NH4Cl.gro -p charmm-gui/topol.top -maxwarn 1
# Out:
#                  :-) GROMACS - gmx grompp, 2025.1-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.1/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.1
# Working dir:  /Users/heiley/Desktop/SURP/1050
# Command line:
#   gmx grompp -f charmm-gui/step4.1_equilibration.mdp -o step5_equilibration.tpr -c step4_minimization.gro -r step3_NH4Cl.gro -p charmm-gui/topol.top -maxwarn 1
#
# Setting the LD random seed to -284289037
#
# Generated 1631 of the 1653 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
#
# Generated 833 of the 1653 1-4 parameter combinations
#
# Excluding 2 bonded neighbours molecule type 'TIP3'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'NH4'
#
# turning H bonds into constraints...
#
# Excluding 1 bonded neighbours molecule type 'CLA'
#
# turning H bonds into constraints...
#
# WARNING 1 [file topol.top, line 59]:
#   The following macros were defined in the 'define' mdp field with the -D
#   prefix, but were not used in the topology:
#       POSRES_FC_SC
#       POSRES_FC_BB
#       POSRES
#   If you haven't made a spelling error, either use the macro you defined,
#   or don't define the macro
#
#
# Setting gen_seed to -338237509
#
# Velocities were taken from a Maxwell distribution at 303.15 K
# Analysing residue names:
# There are: 11264      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group NH4 is 2274.00
# Number of degrees of freedom in T-Coupling group CLA is 618.00
# Number of degrees of freedom in T-Coupling group TIP3 is 65097.00
#
# The largest distance between excluded atoms is 0.176 nm between atom 33401 and 33405
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 303.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.239 nm, buffer size 0.039 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 60x60x60, spacing 0.117 0.117 0.117
#
# Estimate for the relative computational load of the PME mesh part: 0.15
#
# This run will generate roughly 7 Mb of data
#
# There was 1 WARNING
#
# GROMACS reminds you: "Here's Another Useful Quote" (S. Boot)

# %% [markdown]
# ### 12. Equilibration run

# %%
# !gmx mdrun -v -deffnm step5_equilibration -s step5_equilibration.tpr
# Out:
#                   :-) GROMACS - gmx mdrun, 2025.1-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.1/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.1
# Working dir:  /Users/heiley/Desktop/SURP/1050
# Command line:
#   gmx mdrun -v -deffnm step5_equilibration -s step5_equilibration.tpr
#
# Reading file step5_equilibration.tpr, VERSION 2025.1-Homebrew (single precision)
# Changing nstlist from 20 to 100, rlist from 1.2 to 1.302
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'Title'
# 125000 steps,    125.0 ps.
# step 124900, remaining wall clock time:    15 s
# Writing final coordinates.
# step 125000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:   157000.957    19625.123      800.0
#                          5h27:05
#                  (ns/day)    (hour/ns)
# Performance:        0.550       43.611
#
# GROMACS reminds you: "During my undergraduate work I concluded that electrostatics is unlikely to be important [for enzymes]" (Arieh Warshel, Nobel lecture 2013)
