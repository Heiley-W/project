# %% [markdown]
# # Hydration Number Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binned_statistic

font2 = {'family':'serif','size':15}

def plot_settings():
    plt.figure(figsize=(20, 6))
    plt.xlabel("Channel Axis (Å)",fontdict = font2)
    plt.ylabel("Coordination Number",fontdict = font2)
    plt.yticks(np.arange(3, 8, 1))
    plt.grid(True)
    
def hnum_plt(pos, hnum,lab,no):
    cols=["red", "#f47a00", "#62c8d3", "#007191"]
    num_bins = 90

    bin_means, bin_edges, _ = binned_statistic(pos, hnum, statistic='mean', bins=num_bins, range=(min(pos), max(pos)))
    bin_std, _, _ = binned_statistic(pos, hnum, statistic='std', bins=num_bins, range=(min(pos), max(pos)))

    bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])

    plt.errorbar(bin_centers, bin_means, yerr=0, fmt='s', ls="-", capsize=5,label=f"{lab}", color = f"{cols[no]}")

# %% [markdown]
# ## 1. NH4+ ion

# %%
plot_settings()

data = []  
for i in range(1, 4):  
    run_data = np.loadtxt(f'hydration-number/nh4cl-hnum/run{i}/nh4-in-pore.dat')
    data.append(run_data) 

data = np.concatenate(data)
pos = data[:, 2]  
hnum = data[:, 3]  
hnum_plt(pos, hnum,"Model 1")
plt.title("Hydration Number of NH4")
plt.show()

# %%
plot_settings()

data = []  
for i in range(1, 4):  
    run_data = np.loadtxt(f'hydration-number/nh4cl-hnum/run{i}/nh4-in-pore.dat')
    data.append(run_data) 

data = np.concatenate(data)
pos = data[:, 2]  
hnum = data[:, 3]  
hnum_plt(pos, hnum,"Model 1",0)

for j in range (1,4): 
    data = []  
    for i in range(1, 3):  
        run_data = np.loadtxt(f'post-processing/analysis-run{j}.{i}/hnum/nh4-in-pore.dat')
        data.append(run_data) 
        
    data = np.concatenate(data)
    pos = data[:, 2]  
    hnum = data[:, 3]  
    hnum_plt(pos, hnum,f"Model {j+1}",j)

plt.legend(prop={'size': 12})
plt.savefig('/Users/heiley/Desktop/SURP/poster/figures/diff-charge-hyd.png', dpi=500)
plt.show()

# %% [markdown]
# ## 2. Na+ ion

# %%
data = []  
for i in range(1, 7):  
    run_data = np.loadtxt(f'hydration-number/nacl-hnum/hnum_{i}/na-in-pore.dat')
    data.append(run_data) 

data = np.concatenate(data)
pos = data[:, 2]  
hnum = data[:, 3]  
plot_settings(pos, hnum)
plt.title("Hydration Number of SOD")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binned_statistic

def plot_settings(pos, hnum, label, color):
    num_bins = 90

    bin_means, bin_edges, _ = binned_statistic(pos, hnum, statistic='mean', bins=num_bins, range=(min(pos), max(pos)))
    bin_std, _, _ = binned_statistic(pos, hnum, statistic='std', bins=num_bins, range=(min(pos), max(pos)))

    bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])

    plt.errorbar(bin_centers, bin_means, yerr=0, fmt='s', ls="-", capsize=5, label=label, color=color)

# Create a single figure for all plots
plt.figure(figsize=(20, 6))

# Plot NH4 hydration numbers
data = []  
for i in range(1, 4):  
    run_data = np.loadtxt(f'hydration-number/nh4cl-hnum/run{i}/nh4-in-pore.dat')
    data.append(run_data) 

data = np.concatenate(data)
pos = data[:, 2]  
hnum = data[:, 3]  
plot_settings(pos, hnum, 'NH4+ (Model 1)', 'red')

# Plot SOD hydration numbers
data = []  
for i in range(1, 7):  
    run_data = np.loadtxt(f'hydration-number/nacl-hnum/hnum_{i}/na-in-pore.dat')
    data.append(run_data) 

data = np.concatenate(data)
pos = data[:, 2]  
hnum = data[:, 3]  
plot_settings(pos, hnum, 'Na+', 'blue')

data = []  
for i in range(1, 7):  
    run_data = np.loadtxt(f'hydration-number/nacl-hnum/hnum_{i}/cl-in-pore.dat')
    data.append(run_data) 

data = np.concatenate(data)
pos = data[:, 2]  
hnum = data[:, 3]  
plot_settings(pos, hnum, 'Cl-', 'green')

# Finalize the plot
plt.xlabel("z (Å)",fontdict = font2)
plt.ylabel("Coordination Number",fontdict = font2)
plt.grid(True)
plt.legend(prop={'size': 12})
plt.savefig('/Users/heiley/Desktop/SURP/poster/figures/diff-ion-hyd.png', dpi=500)
plt.show()

# %%
# !cat hydration-number/nh4cl-hnum/run1/nh4_in_pore.tcl
# Out:
# proc mycoordnum {frame} {
#     global out out2  all pro popc  squareR cutoff_O cutoff_H
#
#     ## center system such that bilayer center is at z=0
#     set popc_cen [measure center $popc]
#     set popc_z [lindex $popc_cen 2]
#     $all moveby [list 0 0 -$popc_z]
#     puts -nonewline "frame $frame: popc centered at [lindex [measure center $popc] 2] "
#
#     set pro_cen [measure center $pro]
#     set pro_cen_x [lindex $pro_cen 0]
#     set pro_cen_y [lindex $pro_cen 1]
#
#     set ion_index [[atomselect top "name NZ and (x-$pro_cen_x)*(x-$pro_cen_x)+(y-$pro_cen_y)*(y-$pro_cen_y) < $squareR and z > -40 and z < 48"] get index]; # all ions in channel
#     puts -nonewline "\t [llength $ion_index] ions in channel. "
#
#
#     foreach ionID $ion_index {
# 	      set ion [atomselect top "index $ionID"]
#          set ion_cen [measure center $ion]
#
#          set wto [atomselect top "water and name OH2 and within $cutoff_O of index $ionID"];
# ...

# %%
# !cat hydration-number/nacl-hnum/hnum_1/na_in_pore.tcl
# Out:
# proc mycoordnum {frame} {
#     global out out2  all pro popc  squareR cutoff_O cutoff_H
#
#     ## center system such that bilayer center is at z=0
#     set popc_cen [measure center $popc]
#     set popc_z [lindex $popc_cen 2]
#     $all moveby [list 0 0 -$popc_z]
#     puts -nonewline "frame $frame: popc centered at [lindex [measure center $popc] 2] "
#
#     set pro_cen [measure center $pro]
#     set pro_cen_x [lindex $pro_cen 0]
#     set pro_cen_y [lindex $pro_cen 1]
#
#     set ion_index [[atomselect top "name SOD and (x-$pro_cen_x)*(x-$pro_cen_x)+(y-$pro_cen_y)*(y-$pro_cen_y) < $squareR and z > -40 and z < 48"] get index]; # all ions in channel
#     puts -nonewline "\t [llength $ion_index] ions in channel. "
#
#
#     foreach ionID $ion_index {
# 	      set ion [atomselect top "index $ionID"]
#          set ion_cen [measure center $ion]
#
#          set wto [atomselect top "water and name OH2 and within $cutoff_O of index $ionID"];
# ...
